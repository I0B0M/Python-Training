# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sns
import pandas as pd
import numpy as np
from numpy.random import randn

from pandas import Series,DataFrame

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %%
address = '/Users/ibm/Desktop/Python/mtcars.csv'
cars = pd.read_csv(address)

cars.column = ['car_Names','mpg', 'cyl','disp','hp', 'drat','wt', 'qsec','vs','am',	'gear','carb']
mpg = cars['mpg']
# Out:
# /var/folders/jx/kpyxcvj127sck3_x3vwbtq600000gn/T/ipykernel_18317/4167193187.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   cars.column = ['car_Names','mpg', 'cyl','disp','hp', 'drat','wt', 'qsec','vs','am',	'gear','carb']

# %%
mpg.plot()
# Out:
# <Axes: >

# %%
# Creating Line Chart

df = cars[['cyl','wt','mpg']]
df.plot()
# Out:
# <Axes: >

# %%
# Creating barchart

mpg.plot(kind='bar')
# Out:
# <Axes: >

# %%
mpg.plot(kind='barh')
# Out:
# <Axes: >

# %%
x = [1,2,3,4,5,6]
plt.pie(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [1,2,3,4,5,6]
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mpg.plot(kind='pie')
# Out:
# <Axes: ylabel='mpg'>
