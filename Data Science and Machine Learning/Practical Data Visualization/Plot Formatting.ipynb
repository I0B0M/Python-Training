# %%
import numpy as np
import pandas as pd

from pandas import Series,DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams

import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]

plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wide = [0.5,0.5,0.5,0.9,0.9,0.9,0.5,0.5,0.5]
color = ['turquoise']

plt.bar(x,y,width=wide,color=color, align= 'center')
# Out:
# <BarContainer object of 9 artists>

# %%
address = '/Users/ibm/Desktop/Python/mtcars.csv'

cars = pd.read_csv(address)
cars.column = ['car_Names','mpg', 'cyl','disp','hp', 'drat','wt', 'qsec','vs','am',	'gear','carb']
mpg = cars['mpg']
# Out:
# /var/folders/jx/kpyxcvj127sck3_x3vwbtq600000gn/T/ipykernel_19508/3785991193.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   cars.column = ['car_Names','mpg', 'cyl','disp','hp', 'drat','wt', 'qsec','vs','am',	'gear','carb']

# %%
df = cars[['cyl','mpg','wt']]
df.plot()
# Out:
# <Axes: >

# %%
color_theme = ['pink','turquoise','gold']
df.plot(color=color_theme)
# Out:
# <Axes: >

# %%
z = [1,2,3,4,0.5]
plt.pie(z)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pie_colors = ['#A9A9A9','#FFA07A','#B0E056','#FFE4C4','#BDB76B']
plt.pie(z, colors = pie_colors)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x1 = (1,9)
y1 = (9,1)

plt.plot(x,y)
plt.plot(x1,y1)

# %%
plt.plot(x,y,ls = 'solid',lw=5)
plt.plot(x1,y1, ls = '--',lw =10)

# %%
plt.plot(x,y, marker ='1',mew=20)
plt.plot(x1,y1,marker = '+',mew=15)
